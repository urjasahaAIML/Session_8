# %% [markdown]
# <a href="https://colab.research.google.com/github/tapasML/Session_8/blob/main/Session_8_Resnet18_Modular.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load the controller module (main.py)
#
# ---

# %%
import main
from main import *

# %% [markdown]
# # Load data (dataloader.py)
#
# ---

# %%
loaddata()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Display few images from training data (utils.py)
#
# ---

# %%
displaysampleimage()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# shape of images torch.Size([300, 3, 32, 32])
#  deer   dog  deer  deer

# %% [markdown]
# # Define a Resnet18 model and create one (model_resnet.py)
#
# ---

# %%
# training module create a Resnet18 model
model = createmodel()

# %% [markdown]
# # Display model summary for grayscale image. (training.py)
#
# ---
#
#
#
# Note: I am using single channel image for training

# %%
# training module prints model summary
summary(model, input_size=(1, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]             576
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
# ...

# %% [markdown]
# # Prepare to train the model. Define loss function, optimizer, scheduler (training.py)
#
# ---

# %%
# before training, define the loss function, optimizer, scheduler
definelossfunction()

# %% [markdown]
# # Train the model for given number of epochs
#
# ---

# %%
model = trainmodel()
# Out:
# torch.Size([300, 1, 32, 32]) torch.Size([300])
# [1,    40] loss: 0.040
# [1,    80] loss: 0.033
# [1,   120] loss: 0.029
# [1,   160] loss: 0.026
# torch.Size([300, 1, 32, 32]) torch.Size([300])
# [2,    40] loss: 0.023
# [2,    80] loss: 0.022
# [2,   120] loss: 0.020
# [2,   160] loss: 0.019
# torch.Size([300, 1, 32, 32]) torch.Size([300])
# [3,    40] loss: 0.018
# [3,    80] loss: 0.017
# [3,   120] loss: 0.017
# [3,   160] loss: 0.015
# torch.Size([300, 1, 32, 32]) torch.Size([300])
# [4,    40] loss: 0.015
# [4,    80] loss: 0.014
# [4,   120] loss: 0.014
# [4,   160] loss: 0.014
# torch.Size([300, 1, 32, 32]) torch.Size([300])
# [5,    40] loss: 0.013
# [5,    80] loss: 0.013
# [5,   120] loss: 0.012
# [5,   160] loss: 0.012
# torch.Size([300, 1, 32, 32]) torch.Size([300])
# [6,    40] loss: 0.012
# [6,    80] loss: 0.011
# [6,   120] loss: 0.012
# [6,   160] loss: 0.011
# torch.Size([300, 1, 32, 32]) torch.Size([300])
# [7,    40] loss: 0.011
# [7,    80] loss: 0.010
# ...

# %% [markdown]
# # Test the model (testing.py)
#
# ---

# %%
testmodel(model)
# Out:
# Accuracy of the network on the 10000 test images: 88.30 %

# %% [markdown]
# # Display classwise test statistics (testing.py)
#
# ---

# %%
stats_classified(model)
# Out:
# Accuracy of plane : 95 %
# Accuracy of   car : 100 %
# Accuracy of  bird : 82 %
# Accuracy of   cat : 88 %
# Accuracy of  deer : 78 %
# Accuracy of   dog : 75 %
# Accuracy of  frog : 100 %
# Accuracy of horse : 81 %
# Accuracy of  ship : 100 %
# Accuracy of truck : 90 %
